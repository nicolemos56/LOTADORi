# %% [markdown]
# # 08 – Protected Areas and Ecotourism
#
# Uses Protected Planet / WDPA access points and sample ecotourism sites.

# %%
from pathlib import Path
import pandas as pd
import requests, json, os, re
ROOT = Path.cwd()
if ROOT.name == 'starter_notebooks':
    ROOT = ROOT.parent
DATA = ROOT / 'data'
RAW = DATA / 'raw'
SAMPLE = DATA / 'sample'
RAW.mkdir(parents=True, exist_ok=True)
print('Project root:', ROOT)

# %%
links = pd.DataFrame([
    {'source':'Protected Planet Angola', 'url':'https://www.protectedplanet.net/country/AGO', 'use':'Angola protected areas country page'},
    {'source':'WDPA Download', 'url':'https://www.protectedplanet.net/en/thematic-areas/wdpa', 'use':'Download protected area GIS data'},
])
links

# %%
df = pd.read_csv(SAMPLE / 'angola_tourism_attractions_sample.csv')
df[df['category'].isin(['protected_area','natural_site','beach_coastal','waterfall','coastal_site'])]

# %% [markdown]
# ## How to extend
#
# After downloading WDPA data, filter for Angola and compare protected areas with roads, nearby communities and tourism POIs.
