# %% [markdown]
# # 10 – Final Prototype Template
#
# Use this structure for final team notebooks or demos.

# %%
from pathlib import Path
import pandas as pd
import requests, json, os, re
ROOT = Path.cwd()
if ROOT.name == 'starter_notebooks':
    ROOT = ROOT.parent
DATA = ROOT / 'data'
RAW = DATA / 'raw'
SAMPLE = DATA / 'sample'
RAW.mkdir(parents=True, exist_ok=True)
print('Project root:', ROOT)

# %% [markdown]
# ## 1. Problem statement
#
# Write the selected problem statement and target users.

# %%
# 2. Load data
# Replace with team dataset path or API download
sample = pd.read_csv(SAMPLE / 'angola_tourism_attractions_sample.csv')
sample.head()

# %%
# 3. Clean and prepare data
# Add your cleaning steps here
prototype_df = sample.copy()
prototype_df['prototype_ready'] = True
prototype_df.head()

# %%
# 4. Analysis / AI / GIS method
# Add model, recommendation logic, dashboard analysis, map, or prediction method here
prototype_df.groupby('province').size().reset_index(name='number_of_sites')

# %%
# 5. Export result
out = ROOT / 'data' / 'processed' / 'team_prototype_output.csv'
prototype_df.to_csv(out, index=False)
out

# %% [markdown]
# ## 6. Responsible data note
#
# List source, date accessed, limitations, privacy/bias concerns and how the team reduced risk.
#
# ## 7. Next steps
#
# Explain what would be needed for a pilot with MINTUR, UNDP, tourism operators or local communities.
